# %% [markdown]
# # Clever Real Estate Analysis v5 - SQL-Based Market Scoring

# %%
import pandas as pd
import sqlite3
import re

# %%
# Load and clean data
csv_path = r"C:\Users\kaedi\Documents\Python\Portfolio\projects\clever_real_estate\data\real_estate_original.csv"
try:
    df = pd.read_csv(csv_path, encoding='utf-8')
except:
    df = pd.read_csv(csv_path, encoding='latin-1')

df = df.replace('null', pd.NA).replace('NULL', pd.NA).replace('Null', pd.NA)

bool_cols = ['claimed_profile', 'is_active', 'is_cash_home_buyer', 'bbb_accreditation']
for col in bool_cols:
    if col in df.columns:
        df[col] = df[col].map({'TRUE': True, 'FALSE': False, True: True, False: False}).astype('boolean')

num_cols = ['num_reviews', 'avg_review_rating', 'reviews_last_6_months', 'avg_rating_last_6_months',
            'reviews_last_18_months', 'avg_rating_last_18_months', 'num_months_with_reviews',
            'pct_months_with_review', 'response_rate', 'total_responses', 'months_since_last_review',
            'total_months_active', 'year_first_active', 'num_1_star_reviews', 'bbb_complaints', 
            'google_num_reviews', 'google_avg_review_rating']
for col in num_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

print(f"Loaded {len(df)} companies")
# Out:
# Loaded 4358 companies

# %%
db_path = r"C:\Users\kaedi\Documents\Python\Portfolio\projects\clever_real_estate\data\real_estate.db"
conn = sqlite3.connect(db_path)
df.to_sql('companies_raw', conn, if_exists='replace', index=False)
# Out:
# 4358

# %% [markdown]
# Taking a look to be sure our data is coming through correctly

# %%
df.head(15)
# Out:
#                               company_id  \
# 0   19d84513-a249-41dc-b305-558965c4d2e4
# 1   0e05d3d7-816d-4274-ad37-16d2db36894b
# 2   65a2c249-0a2e-4a77-9233-0db96aeef284
# 3   92e82a5e-160d-4852-adf8-a30e2ad993bc
# 4   f60ca260-203d-4e61-8605-012bdc8965a4
# 5   24beb7cb-15ed-4753-837c-ce83341b33b5
# 6   2484124d-499a-4606-b04d-faa16321af0d
# 7   600a1575-117f-4f2e-8bc1-7101134a8f47
# 8   670cd891-98ea-461e-869c-4caa4c4f6f37
# 9   e22fd275-87f8-47b8-9b1f-18133d31281a
# 10  dd74e9f8-fad6-4750-ba1c-190f499e8059
# 11  436b541e-416e-43c1-9799-1f7ebfb4084a
# 12  f6fde8c3-ff3e-4969-8925-f0ed897ceb41
# 13  5683d991-6095-43ad-84e9-eb9ea99cc4c3
# 14  79f7110f-66be-4720-b104-db30ab756b76
#
#                                                  name  \
# 0                            We Buy Houses Dallas .US
# 1                     Jonas Elber, Real Estate Broker
# 2                    The Smith Financial Relief Group
# 3                       Baker LA Mortgage Note Buyers
# 4                               Mike Buys Houses Fast
# 5                                Favor Home Solutions
# 6                             We Buy Houses Tucson AZ
# 7                              California Cash Buyers
# 8                     Your Trusted Home Buyer Orlando
# 9                                      SLO Cash Buyer
# 10                                   Mike Buys Houses
# 11  Real Estate Mortgage Note Buyers Oklahoma City OK
# 12  Real Estate Mortgage Note Buyers Rancho Cucamo...
# 13                                  Easy House Buyers
# 14                                         Peak Offer
#
#                                               website    phone_number  \
# 0                    http://www.webuyhousesdallas.us/             NaN
# 1                          http://www.jonaselber.com/  (509) 720-8330
# 2                          https://allcashbuyers.org/  (440) 837-3753
# 3   https://www.cashnoteusa.com/real-estate-mortga...  (225) 372-5468
# 4              https://www.mike-buys-houses-fast.com/  (757) 255-5505
# 5   https://favorhomesolutions.com/north-carolina/...  (336) 438-8608
# 6                 http://www.webuyhousestucsonaz.com/  (520) 302-4988
# 7                https://www.californiacashbuyer.com/  (415) 384-9992
# 8   https://www.yourtrustedhomebuyer.com/we-buy-ho...  (855) 483-2097
# 9                       https://www.slocashbuyer.com/  (805) 779-3472
# 10             https://www.mikebuyshousesforcash.com/  (248) 243-4346
# 11  https://www.cashnoteusa.com/mortgage-note-buye...  (405) 900-8210
# 12  http://cashnoteusa.com/real-estate-mortgage-no...  (909) 646-4515
# 13                   https://www.easyhousebuyers.com/  (703) 774-3273
# 14                          https://www.peakoffer.co/  (901) 799-3453
#
#                                               address    office_type  \
# 0                                                 NaN  Local Company
# 1                 12810 E Nora Ave, Spokane, WA 99206            NaN
# 2     227 E SUNSHINE SUITE 228, SPRINGFIELD, MO 65807            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN  Local Company
# 5   717 Green Valley Rd Suite 200 #575, Greensboro...  Local Company
# 6                                                 NaN            NaN
# 7                                                 NaN  Local Company
# 8                                                 NaN  Local Company
# 9                                                 NaN  Local Company
# 10              19543 Harman St, Melvindale, MI 48122            NaN
# 11                                                NaN         Branch
# 12                                                NaN         Branch
# 13      3060 Williams Dr Suite 300, Fairfax, VA 22031            NaN
# 14             6000 Poplar Ave STE, Memphis, TN 38119  Local Company
#
#     claimed_profile  is_active                     parent_company_id  \
# 0             False       True  19d84513-a249-41dc-b305-558965c4d2e4
# 1             False       True  0e05d3d7-816d-4274-ad37-16d2db36894b
# 2             False      False  65a2c249-0a2e-4a77-9233-0db96aeef284
# 3             False       True  90d16122-e30c-4cf5-9415-c9e08222e33a
# 4             False       True  f60ca260-203d-4e61-8605-012bdc8965a4
# 5             False       True  24beb7cb-15ed-4753-837c-ce83341b33b5
# 6             False      False  2484124d-499a-4606-b04d-faa16321af0d
# 7             False       True  600a1575-117f-4f2e-8bc1-7101134a8f47
# 8             False       True  670cd891-98ea-461e-869c-4caa4c4f6f37
# 9             False       True  e22fd275-87f8-47b8-9b1f-18133d31281a
# 10            False       True  dd74e9f8-fad6-4750-ba1c-190f499e8059
# 11            False       True  90d16122-e30c-4cf5-9415-c9e08222e33a
# 12            False       True  90d16122-e30c-4cf5-9415-c9e08222e33a
# 13            False       True  5683d991-6095-43ad-84e9-eb9ea99cc4c3
# 14            False       True  79f7110f-66be-4720-b104-db30ab756b76
#
#     is_cash_home_buyer  ...  \
# 0                 True  ...
# 1                 True  ...
# 2                 True  ...
# 3                 True  ...
# 4                 True  ...
# 5                 True  ...
# 6                 True  ...
# 7                 True  ...
# 8                 True  ...
# 9                 True  ...
# 10                True  ...
# 11                True  ...
# 12                True  ...
# 13                True  ...
# 14                True  ...
#
#                                      bbb_reviews_link bbb_review_score  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3   https://www.bbb.org/us/la/baker/profile/home-b...              NaN
# 4                                                 NaN              NaN
# 5   https://www.bbb.org/us/tn/murfreesboro/profile...              NaN
# 6                                                 NaN              NaN
# 7   https://www.bbb.org/us/ca/san-bruno/profile/re...              NaN
# 8                                                 NaN              NaN
# 9   https://www.bbb.org/us/ca/san-luis-obispo/prof...              NaN
# 10                                                NaN              NaN
# 11                                                NaN              NaN
# 12                                                NaN              NaN
# 13                                                NaN              NaN
# 14  https://www.bbb.org/us/tn/memphis/profile/real...              NaN
#
#    bbb_reviews  bbb_complaints  bbb_accreditation  bbb_file_opened  \
# 0          NaN             NaN               <NA>              NaN
# 1          NaN             NaN               <NA>              NaN
# 2          NaN             NaN               <NA>              NaN
# 3          NaN             NaN              False       2020-01-03
# 4          NaN             NaN               <NA>              NaN
# 5          NaN             NaN               <NA>              NaN
# 6          NaN             NaN               <NA>              NaN
# 7          NaN             NaN               True       2019-06-19
# 8          NaN             NaN               <NA>              NaN
# 9          NaN             NaN               True       2022-04-27
# 10         NaN             NaN               <NA>              NaN
# 11         NaN             NaN               <NA>              NaN
# 12         NaN             NaN               <NA>              NaN
# 13         NaN             NaN               <NA>              NaN
# 14         NaN             NaN              False       2023-01-05
#
#     bbb_rating                                 google_profile_url  \
# 0          NaN                                                NaN
# 1          NaN  https://www.google.com/maps/place/Jonas+Elber%...
# 2          NaN  https://www.google.com/maps/place/Smith+Financ...
# 3            A                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7           A+                                                NaN
# 8          NaN                                                NaN
# 9           A+  https://www.google.com/maps/place/SLO+Cash+Buy...
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# 13         NaN  https://www.google.com/maps/place/Easy+House+B...
# 14          A+  https://www.google.com/maps/place/Peak+Offer/@...
#
#     google_num_reviews  google_avg_review_rating
# 0                  NaN                       NaN
# 1                 67.0                  4.820896
# 2                  3.0                  5.000000
# 3                  NaN                       NaN
# 4                  NaN                       NaN
# 5                  NaN                       NaN
# 6                  NaN                       NaN
# 7                  NaN                       NaN
# 8                  NaN                       NaN
# 9                  8.0                  5.000000
# 10                 NaN                       NaN
# 11                 NaN                       NaN
# 12                 NaN                       NaN
# 13                12.0                  4.666667
# 14                16.0                  4.937500
#
# [15 rows x 48 columns]

# %% [markdown]
# We want to have this dataset be easily scored per market for the final use case so we'll fill in gaps wherever we can and ultimately explode the data to have 1 row per market, allowing a company to be represented in as many markets as appropriate

# %%
def split_on_commas(val):
    """Split a comma-separated string into clean items. Does NOT split on spaces."""
    if pd.isna(val):
        return []
    s = str(val).strip()
    if not s or s.lower() in {"null", "none", "nan"}:
        return []
    return [p.strip() for p in s.split(",") if p.strip()]

def extract_city_state_from_address(addr):
    """
    Extract City + 2-letter State from common US addresses like:
    '717 Green Valley Rd..., Greensboro, NC 27408'
    Returns 'City, ST' or None.
    """
    if pd.isna(addr):
        return None
    s = str(addr).strip()
    if not s:
        return None

    m = re.search(r",\s*([^,]+?)\s*,\s*([A-Z]{2})\b(?:\s*\d{5}(?:-\d{4})?)?\s*$", s)
    if m:
        city = m.group(1).strip()
        st = m.group(2).strip()
        return f"{city}, {st}"
    return None

# Explode markets - include ALL columns from original dataset
rows = []
for _, row in df.iterrows():
    markets = []

    # 1) Cities -> City, State (using states field if present)
    cities = split_on_commas(row.get("cities"))
    if cities:
        state = row.get("states", "")
        if pd.notna(state) and str(state).strip():
            markets = [f"{c}, {str(state).strip()}" for c in cities]
        else:
            markets = cities[:]  # no state available, keep city only

    # 2) Counties -> "X County, State"
    if not markets:
        counties = split_on_commas(row.get("counties"))
        if counties:
            state = row.get("states", "")
            if pd.notna(state) and str(state).strip():
                markets = [f"{c} County, {str(state).strip()}" for c in counties]
            else:
                markets = [f"{c} County" for c in counties]

    # 3) States list (can be "North Carolina, South Carolina")
    if not markets:
        markets = split_on_commas(row.get("states"))

    # 4) location_tag fallback
    if not markets and pd.notna(row.get("location_tag")) and str(row.get("location_tag")).strip():
        markets = [str(row.get("location_tag")).strip()]

    # 5) NEW: address-derived fallback (City, ST) if still nothing
    if not markets:
        addr_market = extract_city_state_from_address(row.get("address"))
        if addr_market:
            markets = [addr_market]

    # 6) Unknown
    if not markets:
        markets = ["Unknown"]

    for m in markets:
        row_data = {"company_id": row["company_id"], "company_name": row["name"], "market": m}
        for col in df.columns:
            if col not in ["company_id", "name"]:
                row_data[col] = row.get(col)
        rows.append(row_data)

df_markets = pd.DataFrame(rows)
df_markets.to_sql("market_company", conn, if_exists="replace", index=False)
print(f"Created market_company: {len(df_markets)} rows, {df_markets['market'].nunique()} markets")

# Optional QA: spot-check a known multi-city row explodes into multiple rows
# print(df_markets[df_markets["company_name"].str.contains("California Cash Buyers", na=False)][["company_name","market"]].head(50))
# Out:
# Created market_company: 26891 rows, 9443 markets

# %% [markdown]
# Looking good! We have gone from 4k rows to 27k rows

# %%
query = """
SELECT * FROM market_company LIMIT 15
"""
dfview = pd.read_sql_query(query, conn)
dfview
# Out:
#                               company_id                      company_name  \
# 0   19d84513-a249-41dc-b305-558965c4d2e4          We Buy Houses Dallas .US
# 1   19d84513-a249-41dc-b305-558965c4d2e4          We Buy Houses Dallas .US
# 2   0e05d3d7-816d-4274-ad37-16d2db36894b   Jonas Elber, Real Estate Broker
# 3   65a2c249-0a2e-4a77-9233-0db96aeef284  The Smith Financial Relief Group
# 4   92e82a5e-160d-4852-adf8-a30e2ad993bc     Baker LA Mortgage Note Buyers
# 5   f60ca260-203d-4e61-8605-012bdc8965a4             Mike Buys Houses Fast
# 6   24beb7cb-15ed-4753-837c-ce83341b33b5              Favor Home Solutions
# 7   2484124d-499a-4606-b04d-faa16321af0d           We Buy Houses Tucson AZ
# 8   600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 9   600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 10  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 11  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 12  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 13  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 14  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
#
#                         market  \
# 0                Dallas, Texas
# 1                Frisco, Texas
# 2          Spokane, Washington
# 3        Springfield, Missouri
# 4                      Unknown
# 5         Chesapeake, Virginia
# 6               Greensboro, NC
# 7                      Unknown
# 8          Alameda, California
# 9          Antioch, California
# 10        Berkeley, California
# 11  Citrus Heights, California
# 12         Concord, California
# 13       Cupertino, California
# 14       Daly City, California
#
#                                               website    phone_number  \
# 0                    http://www.webuyhousesdallas.us/            None
# 1                    http://www.webuyhousesdallas.us/            None
# 2                          http://www.jonaselber.com/  (509) 720-8330
# 3                          https://allcashbuyers.org/  (440) 837-3753
# 4   https://www.cashnoteusa.com/real-estate-mortga...  (225) 372-5468
# 5              https://www.mike-buys-houses-fast.com/  (757) 255-5505
# 6   https://favorhomesolutions.com/north-carolina/...  (336) 438-8608
# 7                 http://www.webuyhousestucsonaz.com/  (520) 302-4988
# 8                https://www.californiacashbuyer.com/  (415) 384-9992
# 9                https://www.californiacashbuyer.com/  (415) 384-9992
# 10               https://www.californiacashbuyer.com/  (415) 384-9992
# 11               https://www.californiacashbuyer.com/  (415) 384-9992
# 12               https://www.californiacashbuyer.com/  (415) 384-9992
# 13               https://www.californiacashbuyer.com/  (415) 384-9992
# 14               https://www.californiacashbuyer.com/  (415) 384-9992
#
#                                               address    office_type  \
# 0                                                None  Local Company
# 1                                                None  Local Company
# 2                 12810 E Nora Ave, Spokane, WA 99206           None
# 3     227 E SUNSHINE SUITE 228, SPRINGFIELD, MO 65807           None
# 4                                                None           None
# 5                                                None  Local Company
# 6   717 Green Valley Rd Suite 200 #575, Greensboro...  Local Company
# 7                                                None           None
# 8                                                None  Local Company
# 9                                                None  Local Company
# 10                                               None  Local Company
# 11                                               None  Local Company
# 12                                               None  Local Company
# 13                                               None  Local Company
# 14                                               None  Local Company
#
#     claimed_profile  is_active                     parent_company_id  ...  \
# 0                 0          1  19d84513-a249-41dc-b305-558965c4d2e4  ...
# 1                 0          1  19d84513-a249-41dc-b305-558965c4d2e4  ...
# 2                 0          1  0e05d3d7-816d-4274-ad37-16d2db36894b  ...
# 3                 0          0  65a2c249-0a2e-4a77-9233-0db96aeef284  ...
# 4                 0          1  90d16122-e30c-4cf5-9415-c9e08222e33a  ...
# 5                 0          1  f60ca260-203d-4e61-8605-012bdc8965a4  ...
# 6                 0          1  24beb7cb-15ed-4753-837c-ce83341b33b5  ...
# 7                 0          0  2484124d-499a-4606-b04d-faa16321af0d  ...
# 8                 0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 9                 0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 10                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 11                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 12                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 13                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 14                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
#
#                                      bbb_reviews_link bbb_review_score  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4   https://www.bbb.org/us/la/baker/profile/home-b...             None
# 5                                                None             None
# 6   https://www.bbb.org/us/tn/murfreesboro/profile...             None
# 7                                                None             None
# 8   https://www.bbb.org/us/ca/san-bruno/profile/re...             None
# 9   https://www.bbb.org/us/ca/san-bruno/profile/re...             None
# 10  https://www.bbb.org/us/ca/san-bruno/profile/re...             None
# 11  https://www.bbb.org/us/ca/san-bruno/profile/re...             None
# 12  https://www.bbb.org/us/ca/san-bruno/profile/re...             None
# 13  https://www.bbb.org/us/ca/san-bruno/profile/re...             None
# 14  https://www.bbb.org/us/ca/san-bruno/profile/re...             None
#
#    bbb_reviews bbb_complaints  bbb_accreditation  bbb_file_opened  bbb_rating  \
# 0         None           None                NaN             None        None
# 1         None           None                NaN             None        None
# 2         None           None                NaN             None        None
# 3         None           None                NaN             None        None
# 4         None           None                0.0       2020-01-03           A
# 5         None           None                NaN             None        None
# 6         None           None                NaN             None        None
# 7         None           None                NaN             None        None
# 8         None           None                1.0       2019-06-19          A+
# 9         None           None                1.0       2019-06-19          A+
# 10        None           None                1.0       2019-06-19          A+
# 11        None           None                1.0       2019-06-19          A+
# 12        None           None                1.0       2019-06-19          A+
# 13        None           None                1.0       2019-06-19          A+
# 14        None           None                1.0       2019-06-19          A+
#
#                                    google_profile_url  google_num_reviews  \
# 0                                                None                 NaN
# 1                                                None                 NaN
# 2   https://www.google.com/maps/place/Jonas+Elber%...                67.0
# 3   https://www.google.com/maps/place/Smith+Financ...                 3.0
# 4                                                None                 NaN
# 5                                                None                 NaN
# 6                                                None                 NaN
# 7                                                None                 NaN
# 8                                                None                 NaN
# 9                                                None                 NaN
# 10                                               None                 NaN
# 11                                               None                 NaN
# 12                                               None                 NaN
# 13                                               None                 NaN
# 14                                               None                 NaN
#
#     google_avg_review_rating
# 0                        NaN
# 1                        NaN
# 2                   4.820896
# 3                   5.000000
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
#
# [15 rows x 49 columns]

# %% [markdown]
# We ran the above cleaning and housekeeping steps in python but I prefer SQL for analysis so we'll use that going forward to generate scores. Had to rework some of it because I'm used to the slick features of snowflake SQL, but it should read ok in the old SQLITE syntax

# %%
# SQL scoring
sql = """
DROP TABLE IF EXISTS market_company_scored;
CREATE TABLE market_company_scored AS
WITH base_reviews AS (
    SELECT
        company_id,
        company_name,
        market,
        is_active,
        is_cash_home_buyer,

        /* Best available rating */
        COALESCE(
            NULLIF(google_avg_review_rating, 0),
            NULLIF(avg_review_rating, 0),
            NULLIF(avg_rating_last_18_months, 0),
            NULLIF(avg_rating_last_6_months, 0)
        ) AS best_rating,

        /* Best available review count */
        COALESCE(
            NULLIF(google_num_reviews, 0),
            NULLIF(num_reviews, 0),
            NULLIF(reviews_last_18_months, 0),
            NULLIF(reviews_last_6_months, 0)
        ) AS best_reviews,

        months_since_last_review,
        reviews_last_6_months,
        pct_months_with_review,
        response_rate,
        total_responses,
        year_first_active,
        total_months_active,
        bbb_rating,
        bbb_accreditation,
        bbb_complaints,
        website,
        phone_number,
        address,
        google_profile_url

    FROM market_company
),
-- Necessary because legacy SQL won't allow us to use the 
bay_prep AS (
    SELECT
        *,
        CAST(best_reviews AS REAL) AS v,
        4.3 AS prior_mean, -- derived from all scores in the dataset, setting everyone on equal default footing
        20.0 AS prior_weight -- helps out smaller companies with less reviews, provides moderate smoothing
    FROM base_reviews
),
bayesian AS (
    SELECT
        *,
        v,
        prior_mean,
        prior_weight,

        CASE
            WHEN best_reviews > 0 THEN
                (v / (v + prior_weight)) * best_rating +
                (prior_weight / (v + prior_weight)) * prior_mean
            ELSE NULL
        END AS bayes_rating

    FROM bay_prep
)

SELECT
    company_id,
    company_name,
    market,
    is_active,
    is_cash_home_buyer,
    best_rating,
    best_reviews,
    bayes_rating,

    /* ---------------------------
       Customer Experience Score
    ---------------------------- */
    CASE
        WHEN best_reviews > 0 THEN
            0.75 *
                MIN(
                    MAX((bayes_rating - 3.0) / 2.0, 0), -- 3 is not a great score, treat it as the floor, better rating closer to 5
                    1
                )
            +
            0.25 *
                (LOG(1.0 + best_reviews) / LOG(1.0 + 604.0)) -- max number of reviews
        ELSE NULL
    END AS customer_experience,

    /* ---------------------------
       Activity Signals
    ---------------------------- */

    CASE
        WHEN months_since_last_review IS NOT NULL THEN
            1.0 - MIN(months_since_last_review / 24.0, 1.0) -- we're considering more than 24 months stale
        ELSE NULL
    END AS recency,

    CASE
        WHEN reviews_last_6_months > 0 THEN
            LOG(1.0 + reviews_last_6_months) / LOG(1.0 + 118.0) -- max number of recent reviews
        ELSE NULL
    END AS velocity,

    pct_months_with_review AS consistency,

    CASE
        WHEN response_rate IS NOT NULL THEN
            response_rate *
            MIN(1.0, COALESCE(total_responses, 0) / 20.0) -- high response rate is considered better the more responses you have, fully eligible for best score at 20 
        ELSE NULL
    END AS responsiveness,

    /* ---------------------------
       Age / Credibility
    ---------------------------- */

    CASE
        WHEN year_first_active IS NOT NULL THEN
            MIN((2026 - year_first_active) / 10.0, 1.0)
        WHEN total_months_active IS NOT NULL THEN
            MIN((total_months_active / 12.0) / 10.0, 1.0)
        ELSE NULL
    END AS age_score,

    CASE bbb_rating
        WHEN 'A+' THEN 1.00
        WHEN 'A'  THEN 0.95
        WHEN 'A-' THEN 0.90
        WHEN 'B+' THEN 0.85
        WHEN 'B'  THEN 0.80
        WHEN 'B-' THEN 0.75
        WHEN 'C+' THEN 0.70
        WHEN 'C'  THEN 0.65
        WHEN 'C-' THEN 0.60
        WHEN 'D+' THEN 0.55
        WHEN 'D'  THEN 0.50
        WHEN 'D-' THEN 0.45
        WHEN 'F'  THEN 0.10
        ELSE NULL
    END AS bbb_letter_score,

    /* ---------------------------
       Presence Score
    ---------------------------- */

    (
        CASE WHEN website IS NOT NULL AND website <> '' THEN 1 ELSE 0 END +
        CASE WHEN phone_number IS NOT NULL AND phone_number <> '' THEN 1 ELSE 0 END +
        CASE WHEN address IS NOT NULL AND address <> '' THEN 1 ELSE 0 END +
        CASE WHEN google_profile_url IS NOT NULL AND google_profile_url <> '' THEN 1 ELSE 0 END
    ) / 4.0 AS presence,

    /* ---------------------------
       Raw Fields for Debug / QA
    ---------------------------- */

    months_since_last_review,
    reviews_last_6_months,
    pct_months_with_review,
    response_rate,
    total_responses,
    year_first_active,
    total_months_active,
    bbb_rating,
    bbb_accreditation,
    bbb_complaints,
    website,
    phone_number,
    address,
    google_profile_url

FROM bayesian;
"""
conn.executescript(sql)
print("Created market_company_scored")
# Out:
# Created market_company_scored

# %% [markdown]
# The below only needed to be run once to add columns to hold our scores, we comment it out for the rest of development

# %%
# conn.executescript("""
# ALTER TABLE market_company_scored ADD COLUMN local_activity REAL;
# ALTER TABLE market_company_scored ADD COLUMN credibility REAL;
# ALTER TABLE market_company_scored ADD COLUMN confidence_multiplier REAL;
# ALTER TABLE market_company_scored ADD COLUMN final_score REAL;
# ALTER TABLE market_company_scored ADD COLUMN is_excluded INTEGER;
# ALTER TABLE market_company_scored ADD COLUMN penalty REAL;
# ALTER TABLE market_company_scored ADD COLUMN final_score_adjusted REAL;
# """)

# %%
conn.executescript("""
DROP VIEW IF EXISTS v_market_company_scored_full;

CREATE VIEW v_market_company_scored_full AS
WITH joined AS (
  SELECT
    mc.*,
    sc.best_rating, sc.best_reviews, sc.customer_experience,
    sc.recency, sc.velocity, sc.consistency, sc.responsiveness,
    sc.age_score, sc.bbb_letter_score, sc.presence
  FROM market_company mc
  LEFT JOIN market_company_scored sc
    ON sc.company_id = mc.company_id
   AND sc.market      = mc.market
),
c AS (
  SELECT
    j.*,

    /* derived components */
    COALESCE(recency,0)*0.35 + COALESCE(velocity,0)*0.25 + COALESCE(consistency,0)*0.25 + COALESCE(responsiveness,0)*0.15 AS local_activity,
    COALESCE(age_score,0)*0.45 + COALESCE(bbb_letter_score,0)*0.35 + COALESCE(presence,0)*0.20 AS credibility,

    0.85 + 0.15 * (
      (CASE WHEN best_rating IS NOT NULL AND best_reviews IS NOT NULL THEN 1 ELSE 0 END
     + CASE WHEN bbb_rating IS NOT NULL OR bbb_accreditation=1 OR bbb_complaints IS NOT NULL THEN 1 ELSE 0 END
     + CASE WHEN months_since_last_review IS NOT NULL OR reviews_last_6_months IS NOT NULL THEN 1 ELSE 0 END
     + CASE WHEN year_first_active IS NOT NULL OR total_months_active IS NOT NULL THEN 1 ELSE 0 END
      ) / 4.0
    ) AS confidence_multiplier,

    CASE
      WHEN COALESCE(is_active,0)=0 OR COALESCE(is_cash_home_buyer,0)=0 OR (best_rating<=2.5 AND COALESCE(num_reviews,0)>=10)
      THEN 1 ELSE 0
    END AS is_excluded

  FROM joined j
),
final_score AS (
  SELECT
    c.*,

    CASE
      WHEN customer_experience IS NOT NULL
      THEN 100.0 * (0.40*credibility + 0.35*customer_experience + 0.25*local_activity) * confidence_multiplier
      ELSE 100.0 * (0.40*credibility + 0.25*local_activity) * confidence_multiplier
    END AS final_score,

    (0
     + CASE WHEN num_1_star_reviews IS NOT NULL AND COALESCE(num_reviews,0)>0
             AND (CAST(num_1_star_reviews AS REAL)/CAST(num_reviews AS REAL))>0.25 AND num_reviews>=10
            THEN 10 ELSE 0 END
     + CASE WHEN months_since_last_review>=24 THEN 5 ELSE 0 END
    ) AS penalty

  FROM c
)
SELECT
  f.*,
  CASE WHEN final_score IS NULL THEN NULL ELSE MAX(0, final_score - COALESCE(penalty,0)) END AS final_score_adjusted
FROM final_Score f;
""")

# %%
mfquery = """
SELECT * FROM v_market_company_scored_full LIMIT 15
"""
mfdf = pd.read_sql_query(mfquery, conn)
mfdf
# Out:
#                               company_id                      company_name  \
# 0   19d84513-a249-41dc-b305-558965c4d2e4          We Buy Houses Dallas .US
# 1   19d84513-a249-41dc-b305-558965c4d2e4          We Buy Houses Dallas .US
# 2   0e05d3d7-816d-4274-ad37-16d2db36894b   Jonas Elber, Real Estate Broker
# 3   65a2c249-0a2e-4a77-9233-0db96aeef284  The Smith Financial Relief Group
# 4   92e82a5e-160d-4852-adf8-a30e2ad993bc     Baker LA Mortgage Note Buyers
# 5   f60ca260-203d-4e61-8605-012bdc8965a4             Mike Buys Houses Fast
# 6   24beb7cb-15ed-4753-837c-ce83341b33b5              Favor Home Solutions
# 7   24beb7cb-15ed-4753-837c-ce83341b33b5              Favor Home Solutions
# 8   2484124d-499a-4606-b04d-faa16321af0d           We Buy Houses Tucson AZ
# 9   600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 10  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 11  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 12  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 13  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
# 14  600a1575-117f-4f2e-8bc1-7101134a8f47            California Cash Buyers
#
#                         market  \
# 0                Dallas, Texas
# 1                Frisco, Texas
# 2          Spokane, Washington
# 3        Springfield, Missouri
# 4                      Unknown
# 5         Chesapeake, Virginia
# 6               Greensboro, NC
# 7               Greensboro, NC
# 8                      Unknown
# 9          Alameda, California
# 10         Antioch, California
# 11        Berkeley, California
# 12  Citrus Heights, California
# 13         Concord, California
# 14       Cupertino, California
#
#                                               website    phone_number  \
# 0                    http://www.webuyhousesdallas.us/            None
# 1                    http://www.webuyhousesdallas.us/            None
# 2                          http://www.jonaselber.com/  (509) 720-8330
# 3                          https://allcashbuyers.org/  (440) 837-3753
# 4   https://www.cashnoteusa.com/real-estate-mortga...  (225) 372-5468
# 5              https://www.mike-buys-houses-fast.com/  (757) 255-5505
# 6   https://favorhomesolutions.com/north-carolina/...  (336) 438-8608
# 7   https://favorhomesolutions.com/north-carolina/...  (336) 438-8608
# 8                 http://www.webuyhousestucsonaz.com/  (520) 302-4988
# 9                https://www.californiacashbuyer.com/  (415) 384-9992
# 10               https://www.californiacashbuyer.com/  (415) 384-9992
# 11               https://www.californiacashbuyer.com/  (415) 384-9992
# 12               https://www.californiacashbuyer.com/  (415) 384-9992
# 13               https://www.californiacashbuyer.com/  (415) 384-9992
# 14               https://www.californiacashbuyer.com/  (415) 384-9992
#
#                                               address    office_type  \
# 0                                                None  Local Company
# 1                                                None  Local Company
# 2                 12810 E Nora Ave, Spokane, WA 99206           None
# 3     227 E SUNSHINE SUITE 228, SPRINGFIELD, MO 65807           None
# 4                                                None           None
# 5                                                None  Local Company
# 6   717 Green Valley Rd Suite 200 #575, Greensboro...  Local Company
# 7   717 Green Valley Rd Suite 200 #575, Greensboro...  Local Company
# 8                                                None           None
# 9                                                None  Local Company
# 10                                               None  Local Company
# 11                                               None  Local Company
# 12                                               None  Local Company
# 13                                               None  Local Company
# 14                                               None  Local Company
#
#     claimed_profile  is_active                     parent_company_id  ...  \
# 0                 0          1  19d84513-a249-41dc-b305-558965c4d2e4  ...
# 1                 0          1  19d84513-a249-41dc-b305-558965c4d2e4  ...
# 2                 0          1  0e05d3d7-816d-4274-ad37-16d2db36894b  ...
# 3                 0          0  65a2c249-0a2e-4a77-9233-0db96aeef284  ...
# 4                 0          1  90d16122-e30c-4cf5-9415-c9e08222e33a  ...
# 5                 0          1  f60ca260-203d-4e61-8605-012bdc8965a4  ...
# 6                 0          1  24beb7cb-15ed-4753-837c-ce83341b33b5  ...
# 7                 0          1  24beb7cb-15ed-4753-837c-ce83341b33b5  ...
# 8                 0          0  2484124d-499a-4606-b04d-faa16321af0d  ...
# 9                 0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 10                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 11                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 12                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 13                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
# 14                0          1  600a1575-117f-4f2e-8bc1-7101134a8f47  ...
#
#     age_score bbb_letter_score presence local_activity  credibility  \
# 0         NaN              NaN     0.25       0.000000       0.0500
# 1         NaN              NaN     0.25       0.000000       0.0500
# 2         1.0              NaN     1.00       0.322012       0.6500
# 3         0.4              NaN     1.00       0.022821       0.3800
# 4         NaN             0.95     0.50       0.000000       0.4325
# 5         NaN              NaN     0.50       0.000000       0.1000
# 6         0.4              NaN     0.75       0.697732       0.3300
# 7         0.4             1.00     0.75       0.697732       0.6800
# 8         NaN              NaN     0.50       0.000000       0.1000
# 9         NaN             1.00     0.50       0.000000       0.4500
# 10        NaN             1.00     0.50       0.000000       0.4500
# 11        NaN             1.00     0.50       0.000000       0.4500
# 12        NaN             1.00     0.50       0.000000       0.4500
# 13        NaN             1.00     0.50       0.000000       0.4500
# 14        NaN             1.00     0.50       0.000000       0.4500
#
#     confidence_multiplier  is_excluded  final_score  penalty  \
# 0                  0.8500            0     1.700000        0
# 1                  0.8500            0     1.700000        0
# 2                  0.9625            0    59.811708        0
# 3                  0.9625            1    34.577966        5
# 4                  0.8875            0    15.353750        0
# 5                  0.8500            0     3.400000        0
# 6                  0.9625            0    56.255934        0
# 7                  0.9625            0    69.730934        0
# 8                  0.8500            1     3.400000        0
# 9                  0.8875            0    15.975000        0
# 10                 0.8875            0    15.975000        0
# 11                 0.8875            0    15.975000        0
# 12                 0.8875            0    15.975000        0
# 13                 0.8875            0    15.975000        0
# 14                 0.8875            0    15.975000        0
#
#     final_score_adjusted
# 0               1.700000
# 1               1.700000
# 2              59.811708
# 3              29.577966
# 4              15.353750
# 5               3.400000
# 6              56.255934
# 7              69.730934
# 8               3.400000
# 9              15.975000
# 10             15.975000
# 11             15.975000
# 12             15.975000
# 13             15.975000
# 14             15.975000
#
# [15 rows x 66 columns]

# %%
mjquery = """
WITH eligible AS (
  SELECT
    market,
    company_id,
    company_name,
    website,
    phone_number,
    best_rating,
    best_reviews,
    customer_experience,
    credibility,
    local_activity,
    confidence_multiplier,
    penalty,
    final_score_adjusted

  FROM v_market_company_scored_full
  WHERE COALESCE(is_excluded, 0) = 0
    AND final_score_adjusted IS NOT NULL
)
SELECT
  *,
  ROW_NUMBER() OVER (PARTITION BY market ORDER BY final_score_adjusted DESC) AS market_rank
FROM eligible
WHERE market = 'Dallas, Texas'
ORDER BY market_rank 
"""
mjdf = pd.read_sql_query(mjquery, conn)
mjdf
# Out:
#             market                            company_id  \
# 0    Dallas, Texas  83149b17-d61d-4614-9d26-f171ff3aef60
# 1    Dallas, Texas  38265613-42c6-4485-99ad-2292c14dfef0
# 2    Dallas, Texas  6bcb0f29-34ef-4c2b-b3b0-c42583edf3ff
# 3    Dallas, Texas  61235d47-1694-4f91-92cc-14f1d5815318
# 4    Dallas, Texas  54e3ad8e-4cdf-44d7-bb7e-440f0ecf48f4
# ..             ...                                   ...
# 103  Dallas, Texas  414fe30e-46dc-48c7-9824-6e67ba77f7e9
# 104  Dallas, Texas  976242ee-dbbe-40d3-b5bc-a9688ed332ef
# 105  Dallas, Texas  480be679-9856-4234-a361-6b9b9e138b62
# 106  Dallas, Texas  7f7d0fc0-410f-439b-a3b2-067fad31609f
# 107  Dallas, Texas  19d84513-a249-41dc-b305-558965c4d2e4
#
#                  company_name                              website  \
# 0       Big State Home Buyers  https://www.bigstatehomebuyers.com/
# 1        Metroplex Homebuyers     https://metroplexhomebuyers.com/
# 2                     Orchard                  https://Orchard.com
# 3            Home Buying Guys       http://www.homebuyingguys.com/
# 4         TX Cash Home Buyers    https://www.txcashhomebuyers.com/
# ..                        ...                                  ...
# 103   We Buy Houses in DFW TX  https://www.webuyhousesindfwtx.com/
# 104      We Buy Dallas Houses   https://www.webuydallashouses.com/
# 105       Cash Home Offer USA    https://www.cashhomeofferusa.com/
# 106    Simple House Solutions          https://simplehousedfw.com/
# 107  We Buy Houses Dallas .US     http://www.webuyhousesdallas.us/
#
#        phone_number  best_rating  best_reviews  customer_experience  \
# 0    (713) 322-8803     4.738916         203.0             0.844901
# 1    (972) 487-7653     4.860465         129.0             0.859446
# 2    (844) 515-9880     4.353674         803.0             0.768238
# 3    (866) 847-3565     4.948718          78.0             0.851665
# 4    (281) 595-7550     4.790698          43.0             0.760794
# ..              ...          ...           ...                  ...
# 103  (817) 381-6290          NaN           NaN                  NaN
# 104  (254) 272-3743          NaN           NaN                  NaN
# 105  (888) 724-9603          NaN           NaN                  NaN
# 106  (972) 876-3131          NaN           NaN                  NaN
# 107            None          NaN           NaN                  NaN
#
#      credibility  local_activity  confidence_multiplier  penalty  \
# 0          1.000        0.635254                   1.00        0
# 1          1.000        0.560493                   1.00        0
# 2          0.815        0.888848                   1.00        0
# 3          0.910        0.593970                   1.00        0
# 4          0.865        0.668765                   1.00        0
# ..           ...             ...                    ...      ...
# 103        0.100        0.000000                   0.85        0
# 104        0.100        0.000000                   0.85        0
# 105        0.100        0.000000                   0.85        0
# 106        0.100        0.000000                   0.85        0
# 107        0.050        0.000000                   0.85        0
#
#      final_score_adjusted  market_rank
# 0               85.452900            1
# 1               84.092937            2
# 2               81.709517            3
# 3               81.057514            4
# 4               77.946921            5
# ..                    ...          ...
# 103              3.400000          104
# 104              3.400000          105
# 105              3.400000          106
# 106              3.400000          107
# 107              1.700000          108
#
# [108 rows x 14 columns]

# %%
# Close connection when done

conn.close()
print("\nDone!")
